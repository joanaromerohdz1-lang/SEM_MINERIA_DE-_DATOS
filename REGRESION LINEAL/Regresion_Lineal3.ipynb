# %% [markdown]
# **REGRESIÓN LINEAL 3 - EJERCICIOS**

# %% [markdown]
# **Problema 3-PracticaExamenes.csv**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("PracticaExamenes.csv")

print("Primeras filas del dataset:")
print(df.head())

print("\nInformación del dataset:")
print(df.info())
# Out:
# Primeras filas del dataset:
#    horas  puntuacion
# 0      3          64
# 1      4          67
# 2      6          76
# 3      3          65
# 4      5          72
#
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   horas       150 non-null    int64
#  1   puntuacion  150 non-null    int64
# dtypes: int64(2)
# memory usage: 2.5 KB
# None

# %%
print(df.columns)
# Out:
# Index(['horas', 'puntuacion'], dtype='object')

# %%
plt.figure(figsize=(7,5))

plt.scatter(df["horas"], df["puntuacion"])

plt.xlabel("Horas de práctica semanal")
plt.ylabel("Puntuación del examen")
plt.title("Relación entre horas de práctica y puntuación")

plt.show()

# %%
X = df[['horas']]
y = df['puntuacion']

# %%
modelo = LinearRegression()

modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
pendiente = modelo.coef_[0]
intercepto = modelo.intercept_

print("Pendiente:", pendiente)
print("Intercepto:", intercepto)

print(f"Ecuación: Puntuacion = {pendiente:.2f} * Horas + {intercepto:.2f}")
# Out:
# Pendiente: 5.207841550974414
# Intercepto: 47.06311668424323
# Ecuación: Puntuacion = 5.21 * Horas + 47.06

# %%
y_pred = modelo.predict(X)

r2 = r2_score(y, y_pred)

print("Coeficiente de determinación (R²):", r2)
# Out:
# Coeficiente de determinación (R²): 0.9759322302383702

# %%
plt.figure(figsize=(8,5))

plt.scatter(X, y, label="Datos reales")

plt.plot(X, y_pred, linewidth=2, label="Línea de regresión")

plt.xlabel("Horas de práctica")
plt.ylabel("Puntuación del examen")
plt.title("Regresión lineal: práctica vs puntuación")

ecuacion = f"Puntuacion = {pendiente:.2f} * Horas + {intercepto:.2f}"
plt.text(min(X.values), max(y), ecuacion)

plt.legend()

plt.show()

# %%
def predecir_puntuacion(horas):
    pred = modelo.predict([[horas]])
    return pred[0]

# %%
print("Puntuación esperada para 5 horas de práctica:", predecir_puntuacion(5))
# Out:
# Puntuación esperada para 5 horas de práctica: 73.10232443911529
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
for h in [2,4,6,8,10]:
    print(f"Horas: {h} -> Puntuación estimada: {predecir_puntuacion(h):.2f}")
# Out:
# Horas: 2 -> Puntuación estimada: 57.48
# Horas: 4 -> Puntuación estimada: 67.89
# Horas: 6 -> Puntuación estimada: 78.31
# Horas: 8 -> Puntuación estimada: 88.73
# Horas: 10 -> Puntuación estimada: 99.14
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
