# %% [markdown]
# **--------------REGRESIÓN LINEAL- EJERCICIOS-----------**
#
# ---

# %% [markdown]
# **PROBLEMA1-publicidadVentas.csv**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("PublicidadVentas.csv")
df.head()
# Out:
#    Inversion  Ventas
# 0        1.2     180
# 1        1.5     210
# 2        1.8     250
# 3        2.0     280
# 4        2.2     300

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Inversion  70 non-null     float64
#  1   Ventas     70 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 1.2 KB
# None

# %%
X = df[['Inversion']]
y = df['Ventas']

# %%
modelo = LinearRegression()

modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
pendiente = modelo.coef_[0]
intercepto = modelo.intercept_

print("Pendiente (m):", pendiente)
print("Intercepto (b):", intercepto)

print(f"Ecuación del modelo: Ventas = {pendiente:.2f} * Inversion + {intercepto:.2f}")
# Out:
# Pendiente (m): 80.49762260137459
# Intercepto (b): 112.68348869841918
# Ecuación del modelo: Ventas = 80.50 * Inversion + 112.68

# %%
y_pred = modelo.predict(X)

# %%
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("Error Cuadrático Medio (MSE):", mse)
print("Coeficiente de Determinación (R²):", r2)
# Out:
# Error Cuadrático Medio (MSE): 38.76425545416376
# Coeficiente de Determinación (R²): 0.9997661366378643

# %%
plt.figure(figsize=(8,5))

plt.scatter(X, y, label="Datos reales")

plt.plot(X, y_pred, linewidth=2, label="Línea de regresión")

plt.xlabel("Inversión en Publicidad (miles de dólares)")
plt.ylabel("Unidades Vendidas")
plt.title("Relación entre Inversión en Publicidad y Ventas")

ecuacion = f"Ventas = {pendiente:.2f} * Inversion + {intercepto:.2f}"
plt.text(min(X.values), max(y), ecuacion)

plt.legend()
plt.show()

# %%
def estimar_ventas(inversion):
    prediccion = modelo.predict([[inversion]])
    return prediccion[0]

# %%
estimar_ventas(5)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(515.1716017052921)
